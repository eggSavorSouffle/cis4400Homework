# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import string
import requests

# %%
response = requests.get('https://data.cityofnewyork.us/resource/wz6d-d3jb.json')
print(response.json())
# Out:
# [{'building_id': '344156', 'registration_id': '306009', 'borough': 'BROOKLYN', 'house_number': '161', 'street_name': 'NEWEL STREET', 'postcode': '11222', 'of_dwelling_units': '6', 'infested_dwelling_unit_count': '0', 'eradicated_unit_count': '0', 're_infested_dwelling_unit': '0', 'filing_date': '2021-02-16T00:00:00.000', 'filing_period_start_date': '2019-11-01T00:00:00.000', 'filling_period_end_date': '2020-10-31T00:00:00.000', 'latitude': '40.727680', 'longitude': '-73.949030', 'community_board': '1', 'city_council_district': '33', 'census_tract_2010': '573', 'bin': '3065755', 'bbl': '3026230011', 'nta': 'Greenpoint'}, {'building_id': '358122', 'registration_id': '357464', 'borough': 'BROOKLYN', 'house_number': '389', 'street_name': 'PUTNAM AVENUE', 'postcode': '11216', 'of_dwelling_units': '3', 'infested_dwelling_unit_count': '0', 'eradicated_unit_count': '0', 're_infested_dwelling_unit': '0', 'filing_date': '2023-07-10T00:00:00.000', 'filing_period_start_date': '2021-11-01T00:00:0
# ...

# %%
df = pd.read_json('https://data.cityofnewyork.us/resource/wz6d-d3jb.json')
df.to_csv()
# Out:
# ',building_id,registration_id,borough,house_number,street_name,postcode,of_dwelling_units,infested_dwelling_unit_count,eradicated_unit_count,re_infested_dwelling_unit,filing_date,filing_period_start_date,filling_period_end_date,latitude,longitude,community_board,city_council_district,census_tract_2010,bin,bbl,nta\n0,344156,306009,BROOKLYN,161,NEWEL STREET,11222.0,6,0,0,0,2021-02-16T00:00:00.000,2019-11-01T00:00:00.000,2020-10-31T00:00:00.000,40.72768,-73.94903,1.0,33.0,573.0,3065755.0,3026230011.0,Greenpoint\n1,358122,357464,BROOKLYN,389,PUTNAM AVENUE,11216.0,3,0,0,0,2023-07-10T00:00:00.000,2021-11-01T00:00:00.000,2022-10-31T00:00:00.000,40.684545,-73.945667,3.0,36.0,267.0,3051701.0,3018240063.0,Bedford-Stuyvesant (West)\n2,705843,403865,QUEENS,861,WOODWARD AVENUE,11385.0,4,0,0,0,2021-05-05T00:00:00.000,2019-11-01T00:00:00.000,2020-10-31T00:00:00.000,40.702903,-73.902286,5.0,30.0,585.0,4083378.0,4034830034.0,Ridgewood\n3,877716,379778,BROOKLYN,912,MOTHER GASTON BOULEVARD,11212.0,3,0,
# ...

# %%
df.sample()
# Out:
#      building_id  registration_id borough house_number      street_name  \
# 113        67009           216319   BRONX         2841  EAST 196 STREET
#
#      postcode  of_dwelling_units  infested_dwelling_unit_count  \
# 113   10461.0                  4                             0
#
#      eradicated_unit_count  re_infested_dwelling_unit  ...  \
# 113                      0                          0  ...
#
#     filing_period_start_date  filling_period_end_date  latitude  longitude  \
# 113  2019-11-01T00:00:00.000  2020-10-31T00:00:00.000  40.85396 -73.833079
#
#      community_board  city_council_district  census_tract_2010        bin  \
# 113             10.0                   13.0              300.0  2047636.0
#
#               bbl                                  nta
# 113  2.042430e+09  Pelham Bay-Country Club-City Island
#
# [1 rows x 21 columns]
